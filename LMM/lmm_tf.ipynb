# %%
import csv
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import requests

import tensorflow as tf
import tensorflow_probability as tfp
from sklearn.model_selection import train_test_split


tfd = tfp.distributions
tfb = tfp.bijectors

dtype = tf.float64

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline
plt.style.use('ggplot')

# %%
data = pd.read_csv('All.csv')

data = data.drop(data.columns[0], axis=1)
data.replace([np.inf, -np.inf], np.nan, inplace=True)
data = data.dropna()

y = data['LUMO']
X = data.loc[:, ['MolWt', 'HvAtMolWt', 'RadE', 'ValE', 'NHOH', 'H', 'NO', 'HAcc', 'HDon', 'Rings', 'AlRing',
                 'AroRing', 'SatRing', 'AroCarb', 'AroHet', 'Heteroatoms', 'RotBond', 'SatCarb', 'SatHet', 'C',
                 'N', 'F', 'Halogens', 'Double', 'Triple', 'MaxAbsPartCh', 'MaxPartCh', 'MinPartCh', 'MinAbsPartCh', 'Group']]
list_numerical = X.columns


# split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=10)

# %%
X_train = X_train.astype('int32')
X_test = X_test.astype('int32')

# %%
num_molwt = int(max(X_train['MolWt'])) + 1
num_hvmolwt = int(max(X_train['HvAtMolWt'])) + 1
# num_rade = int(max(X_train['RadE'])) + 1
# num_vale = int(max(X_train['ValE'])) + 1
# num_nhoh = int(max(X_train['NHOH'])) + 1
# num_h = int(max(X_train['H'])) + 1
# num_no = int(max(X_train['NO'])) + 1
# num_hacc = int(max(X_train['HAcc'])) + 1
# num_hdon = int(max(X_train['HDon'])) + 1
# num_rings = int(max(X_train['Rings'])) + 1
# num_alring = int(max(X_train['AlRing'])) + 1
# num_aroring = int(max(X_train['AroRing'])) + 1
# num_satring = int(max(X_train['SatRing'])) + 1
# num_arocarb = int(max(X_train['AroCarb'])) + 1
# num_arohet = int(max(X_train['AroHet'])) + 1
# num_het = int(max(X_train['Heteroatoms'])) + 1
# num_rotbond = int(max(X_train['RotBond'])) + 1
# num_satcarb = int(max(X_train['SatCarb'])) + 1
# num_sathet = int(max(X_train['SatHet'])) + 1
# num_c = int(max(X_train['C'])) + 1
# num_n = int(max(X_train['N'])) + 1
# num_f = int(max(X_train['F'])) + 1
# num_hal = int(max(X_train['Halogens'])) + 1
# num_double = int(max(X_train['Double'])) + 1
# num_triple = int(max(X_train['Triple'])) + 1
# num_maxabs = int(max(X_train['MaxAbsPartCh'])) + 1
# num_maxpart = int(max(X_train['MaxPartCh'])) + 1
# num_minpart = int(max(X_train['MinPartCh'])) + 1
# num_minabs = int(max(X_train['MinAbsPartCh'])) + 1


# num_instructors = max(features_train['instructors']) + 1
# num_departments = max(features_train['departments']) + 1
num_observations = X_train.shape[0]
print('Molecular Weight', num_molwt)
print('Heavy Atom Molecular Weight', num_hvmolwt)
# Out:
# Molecular Weight 3148
# Heavy Atom Molecular Weight 2875

# %%
class LinearMixedEffectModel(tf.Module):
  def __init__(self):
    # Set up fixed effects and other parameters.
    # These are free parameters to be optimized in E-steps
    self._intercept = tf.Variable(0., name="intercept")            # alpha in eq
    self._effect_service = tf.Variable(0., name="effect_service")  #  beta in eq
    self._stddev_molwt = tfp.util.TransformedVariable(
        1., bijector=tfb.Exp(), name="stddev_molwt")               # sigma in eq
    self._stddev_hvmolwt = tfp.util.TransformedVariable(
        1., bijector=tfb.Exp(), name="stddev_hvmolwt")             # sigma in eq
    # self._stddev_rade = tfp.util.TransformedVariable(
    #     1., bijector=tfb.Exp(), name="stddev_rade")                # sigma in eq
    # self._stddev_vale = tfp.util.TransformedVariable(
    #     1., bijector=tfb.Exp(), name="stddev_vale")                # sigma in eq
    # self._stddev_nhoh = tfp.util.TransformedVariable(
    #     1., bijector=tfb.Exp(), name="stddev_nhoh")                # sigma in eq
    # self._stddev_h = tfp.util.TransformedVariable(
    #     1., bijector=tfb.Exp(), name="stddev_h")                   # sigma in eq
    # self._stddev_no = tfp.util.TransformedVariable(
    #     1., bijector=tfb.Exp(), name="stddev_no")                  # sigma in eq
    # self._stddev_hacc = tfp.util.TransformedVariable(
    #     1., bijector=tfb.Exp(), name="stddev_hacc")                # sigma in eq
    # self._stddev_hdon = tfp.util.TransformedVariable(
    #     1., bijector=tfb.Exp(), name="stddev_hdon")                # sigma in eq
    # self._stddev_rings = tfp.util.TransformedVariable(
    #     1., bijector=tfb.Exp(), name="stddev_rings")               # sigma in eq
    # self._stddev_alring = tfp.util.TransformedVariable(
    #     1., bijector=tfb.Exp(), name="stddev_alring")              # sigma in eq
    # self._stddev_aroring = tfp.util.TransformedVariable(
    #     1., bijector=tfb.Exp(), name="stddev_aroring")             # sigma in eq
    # self._stddev_satring = tfp.util.TransformedVariable(
    #     1., bijector=tfb.Exp(), name="stddev_satring")             # sigma in eq
    # self._stddev_arocarb = tfp.util.TransformedVariable(
    #     1., bijector=tfb.Exp(), name="stddev_arocarb")             # sigma in eq
    # self._stddev_arohet = tfp.util.TransformedVariable(
    #     1., bijector=tfb.Exp(), name="stddev_arohet")              # sigma in eq
    # self._stddev_het = tfp.util.TransformedVariable(
    #     1., bijector=tfb.Exp(), name="stddev_het")                 # sigma in eq
    # self._stddev_rotbond = tfp.util.TransformedVariable(
    #     1., bijector=tfb.Exp(), name="stddev_rotbond")             # sigma in eq
    # self._stddev_satcarb = tfp.util.TransformedVariable(
    #     1., bijector=tfb.Exp(), name="stddev_satcarb")             # sigma in eq
    # self._stddev_sathet = tfp.util.TransformedVariable(
    #     1., bijector=tfb.Exp(), name="stddev_sathet")              # sigma in eq
    # self._stddev_c = tfp.util.TransformedVariable(
    #     1., bijector=tfb.Exp(), name="stddev_c")                   # sigma in eq
    # self._stddev_n = tfp.util.TransformedVariable(
    #     1., bijector=tfb.Exp(), name="stddev_n")                   # sigma in eq
    # self._stddev_f = tfp.util.TransformedVariable(
    #     1., bijector=tfb.Exp(), name="stddev_f")                   # sigma in eq
    # self._stddev_hal = tfp.util.TransformedVariable(
    #     1., bijector=tfb.Exp(), name="stddev_hal")                 # sigma in eq
    # self._stddev_double = tfp.util.TransformedVariable(
    #     1., bijector=tfb.Exp(), name="stddev_double")              # sigma in eq
    # self._stddev_triple = tfp.util.TransformedVariable(
    #     1., bijector=tfb.Exp(), name="stddev_triple")              # sigma in eq
    # self._stddev_maxabs = tfp.util.TransformedVariable(
    #     1., bijector=tfb.Exp(), name="stddev_maxabs")              # sigma in eq
    # self._stddev_maxpart = tfp.util.TransformedVariable(
    #     1., bijector=tfb.Exp(), name="stddev_maxpart")             # sigma in eq
    # self._stddev_minabs = tfp.util.TransformedVariable(
    #     1., bijector=tfb.Exp(), name="stddev_minabs")              # sigma in eq
    # self._stddev_minpart = tfp.util.TransformedVariable(
    #     1., bijector=tfb.Exp(), name="stddev_minpart")             # sigma in eq

  def __call__(self, features):
    model = tfd.JointDistributionSequential([
      # Set up random effects.
      tfd.MultivariateNormalDiag(
          loc=tf.zeros(num_molwt, dtype=tf.dtypes.float32),
          scale_diag=self._stddev_molwt * tf.ones(num_molwt)),
      tfd.MultivariateNormalDiag(
          loc=tf.zeros(num_hvmolwt),
          scale_diag=self._stddev_hvmolwt * tf.ones(num_hvmolwt)),
    #   tfd.MultivariateNormalDiag(
    #       loc=tf.zeros(num_rade),
    #       scale_diag=self._stddev_rade * tf.ones(num_rade)),
    #   tfd.MultivariateNormalDiag(
    #       loc=tf.zeros(num_vale),
    #       scale_diag=self._stddev_vale * tf.ones(num_vale)),
    #   tfd.MultivariateNormalDiag(
    #       loc=tf.zeros(num_nhoh),
    #       scale_diag=self._stddev_nhoh * tf.ones(num_nhoh)),
    #   tfd.MultivariateNormalDiag(
    #       loc=tf.zeros(num_h),
    #       scale_diag=self._stddev_h * tf.ones(num_h)),
    #   tfd.MultivariateNormalDiag(
    #       loc=tf.zeros(num_no),
    #       scale_diag=self._stddev_no * tf.ones(num_no)),
    #   tfd.MultivariateNormalDiag(
    #       loc=tf.zeros(num_hacc),
    #       scale_diag=self._stddev_hacc * tf.ones(num_hacc)),
    #   tfd.MultivariateNormalDiag(
    #       loc=tf.zeros(num_hdon),
    #       scale_diag=self._stddev_hdon * tf.ones(num_hdon)),
    #   tfd.MultivariateNormalDiag(
    #       loc=tf.zeros(num_rings),
    #       scale_diag=self._stddev_rings * tf.ones(num_rings)),
    #   tfd.MultivariateNormalDiag(
    #       loc=tf.zeros(num_alring),
    #       scale_diag=self._stddev_alring * tf.ones(num_alring)),
    #   tfd.MultivariateNormalDiag(
    #       loc=tf.zeros(num_aroring),
    #       scale_diag=self._stddev_aroring * tf.ones(num_aroring)),
    #   tfd.MultivariateNormalDiag(
    #       loc=tf.zeros(num_satring),
    #       scale_diag=self._stddev_satring * tf.ones(num_satring)),
    #   tfd.MultivariateNormalDiag(
    #       loc=tf.zeros(num_arocarb),
    #       scale_diag=self._stddev_arocarb * tf.ones(num_arocarb)),
    #   tfd.MultivariateNormalDiag(
    #       loc=tf.zeros(num_arohet),
    #       scale_diag=self._stddev_arohet * tf.ones(num_arohet)),
    #   tfd.MultivariateNormalDiag(
    #       loc=tf.zeros(num_het),
    #       scale_diag=self._stddev_het * tf.ones(num_het)),
    #   tfd.MultivariateNormalDiag(
    #       loc=tf.zeros(num_rotbond),
    #       scale_diag=self._stddev_rotbond * tf.ones(num_rotbond)),
    #   tfd.MultivariateNormalDiag(
    #       loc=tf.zeros(num_satcarb),
    #       scale_diag=self._stddev_satcarb * tf.ones(num_satcarb)),
    #   tfd.MultivariateNormalDiag(
    #       loc=tf.zeros(num_sathet),
    #       scale_diag=self._stddev_sathet * tf.ones(num_sathet)),
    #   tfd.MultivariateNormalDiag(
    #       loc=tf.zeros(num_c),
    #       scale_diag=self._stddev_c * tf.ones(num_c)),
    #   tfd.MultivariateNormalDiag(
    #       loc=tf.zeros(num_n),
    #       scale_diag=self._stddev_n * tf.ones(num_n)),
    #   tfd.MultivariateNormalDiag(
    #       loc=tf.zeros(num_f),
    #       scale_diag=self._stddev_f * tf.ones(num_f)),
    #   tfd.MultivariateNormalDiag(
    #       loc=tf.zeros(num_hal),
    #       scale_diag=self._stddev_hal * tf.ones(num_hal)),
    #   tfd.MultivariateNormalDiag(
    #       loc=tf.zeros(num_double),
    #       scale_diag=self._stddev_double * tf.ones(num_double)),
    #   tfd.MultivariateNormalDiag(
    #       loc=tf.zeros(num_triple),
    #       scale_diag=self._stddev_triple * tf.ones(num_triple)),
    #   tfd.MultivariateNormalDiag(
    #       loc=tf.zeros(num_maxabs),
    #       scale_diag=self._stddev_maxabs * tf.ones(num_maxabs)),
    #   tfd.MultivariateNormalDiag(
    #       loc=tf.zeros(num_maxpart),
    #       scale_diag=self._stddev_maxpart * tf.ones(num_maxpart)),
    #   tfd.MultivariateNormalDiag(
    #       loc=tf.zeros(num_minabs),
    #       scale_diag=self._stddev_minabs * tf.ones(num_minabs)),
    #   tfd.MultivariateNormalDiag(
    #       loc=tf.zeros(num_minpart),
    #       scale_diag=self._stddev_minpart * tf.ones(num_minpart)),
      # This is the likelihood for the observed.
      lambda effect_molwt, effect_hvatmolwt
            #  effect_rade, effect_vale, effect_nhoh, effect_h, effect_no,
            #  effect_hacc, effect_hdon, effect_rings, effect_alring, effect_aroring, effect_satring,
            #  effect_arocarb, effect_arohet, effect_het, effect_rotbond, effect_satcarb, effect_sathet,
            #  effect_c, effect_n, effect_f, effect_hal, effect_double, effect_triple, effect_maxabs,
            #  effect_maxpart, effect_minpart, effect_minabs
             : tfd.Independent(
          tfd.Normal(
              loc=(self._effect_service * X_train["Group"] +
                  tf.gather(effect_molwt, X_train["MolWt"], axis=-1) +
                  tf.gather(effect_hvatmolwt, X_train["HvAtMolWt"], axis=-1) +
                #   tf.gather(effect_rade, X_train['RadE'], axis=-1) +
                #   tf.gather(effect_vale, X_train['ValE'], axis=-1) +
                #   tf.gather(effect_nhoh, X_train['NHOH'], axis=-1) +
                #   tf.gather(effect_h, X_train['H'], axis=-1) +
                #   tf.gather(effect_no, X_train['NO'], axis=-1) +
                #   tf.gather(effect_hacc, X_train['HAcc'], axis=-1) +
                #   tf.gather(effect_hdon, X_train['HDon'], axis=-1) +
                #   tf.gather(effect_rings, X_train['Rings'], axis=-1) +
                #   tf.gather(effect_alring, X_train['AlRing'], axis=-1) +
                #   tf.gather(effect_aroring, X_train['AroRing'], axis=-1) +
                #   tf.gather(effect_satring, X_train['SatRing'], axis=-1) +
                #   tf.gather(effect_arocarb, X_train['AroCarb'], axis=-1) +
                #   tf.gather(effect_arohet, X_train['AroHet'], axis=-1) +
                #   tf.gather(effect_het, X_train['Heteroatoms'], axis=-1) +
                #   tf.gather(effect_rotbond, X_train['RotBond'], axis=-1) +
                #   tf.gather(effect_satcarb, X_train['SatCarb'], axis=-1) +
                #   tf.gather(effect_sathet, X_train['SatHet'], axis=-1) +
                #   tf.gather(effect_c, X_train['C'], axis=-1) +
                #   tf.gather(effect_n, X_train['N'], axis=-1) +
                #   tf.gather(effect_f, X_train['F'], axis=-1) +
                #   tf.gather(effect_hal, X_train['Halogens'], axis=-1) +
                #   tf.gather(effect_double, X_train['Double'], axis=-1) +
                #   tf.gather(effect_triple, X_train['Triple'], axis=-1) +
                #   tf.gather(effect_maxpart, X_train['MaxPartCh'], axis=-1) +
                #   tf.gather(effect_maxabs, X_train['MaxAbsPartCh'], axis=-1) +
                #   tf.gather(effect_minpart, X_train['MinPartCh'], axis=-1) +
                #   tf.gather(effect_minabs, X_train['MinAbsPartCh'], axis=-1) +
                  self._intercept),
              scale=1.),
              reinterpreted_batch_ndims=1)
    ])

    # To enable tracking of the trainable variables via the created distribution,
    # we attach a reference to `self`. Since all TFP objects sub-class
    # `tf.Module`, this means that the following is possible:
    # LinearMixedEffectModel()(features_train).trainable_variables
    # ==> tuple of all tf.Variables created by LinearMixedEffectModel.
    model._to_track = self
    return model
  
lmm_jointdist = LinearMixedEffectModel()
# Conditioned on feature/predictors from the training data
lmm_train = lmm_jointdist(X_train)

# %%
lmm_train.trainable_variables
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 lmm_train.trainable_variables
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/tensorflow/python/module/module.py:171, in Module.trainable_variables(self)
#     157 @property
#     158 def trainable_variables(self):
#     159   """Sequence of trainable variables owned by this module and its submodules.
#     160
#     161   Note: this method uses reflection to find variables on the current instance
#    (...)
#     168     first).
#     169   """
#     170   return tuple(
# --> 171       self._flatten(predicate=_is_trainable_variable, expand_composites=True))
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/tensorflow_probability/python/distributions/joint_distribution.py:374, in JointDistribution._flatten(self, *args, **kwargs)
#     373 def _flatten(self, *args, **kwargs):
# --> 374   self._get_single_sample_distributions()
#     375   return super(JointDistribution, self)._flatten(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/tensorflow_probability/python/distributions/joint_distribution.py:353, in JointDistribution._get_single_sample_distributions(self, candidate_dists)
#     351     ds = candidate_dists
#     352   else:
# --> 353     ds = self._execute_model(
#     354         seed=samplers.zeros_seed(),  # Constant seed for CSE.
#     355         sample_and_trace_fn=trace_distributions_only)
#     356   self._single_sample_distributions[graph_id] = ds
#     357 return ds
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/tensorflow_probability/python/distributions/joint_distribution.py:1047, in JointDistribution._execute_model(self, sample_shape, seed, value, stop_index, sample_and_trace_fn)
#    1045     if stop_index is not None and index == stop_index:
#    1046       break
# -> 1047     d = gen.send(next_value)
#    1048 except StopIteration:
#    1049   pass
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/tensorflow_probability/python/distributions/joint_distribution_sequential.py:399, in _JointDistributionSequential._model_coroutine(self)
#     397 xs = []
#     398 for dist_fn, args in zip(self._dist_fn_wrapped, self._dist_fn_args):
# --> 399   dist = dist_fn(*xs)
#     400   if not args:
#     401     dist = self.Root(dist)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/tensorflow_probability/python/distributions/joint_distribution_sequential.py:610, in _unify_call_signature.<locals>.dist_fn_wrapped(*xs)
#     605 if len(xs) < len(args):
#     606   raise ValueError(
#     607       'Internal Error: Too few inputs provided to {}-th distribution maker '
#     608       '(dist_fn: {}, expected: {}, saw: {}).'.format(
#     609           i, dist_fn, len(args), len(xs)))
# --> 610 return dist_fn(*reversed(xs[-len(args):]))
#
# Cell In[44], line 166, in LinearMixedEffectModel.__call__.<locals>.<lambda>(effect_molwt, effect_hvatmolwt)
#      66 def __call__(self, features):
#      67   model = tfd.JointDistributionSequential([
#      68     # Set up random effects.
#      69     tfd.MultivariateNormalDiag(
#      70         loc=tf.zeros(num_molwt, dtype=tf.dtypes.float32),
#      71         scale_diag=self._stddev_molwt * tf.ones(num_molwt)),
#      72     tfd.MultivariateNormalDiag(
#      73         loc=tf.zeros(num_hvmolwt),
#      74         scale_diag=self._stddev_hvmolwt * tf.ones(num_hvmolwt)),
#      75   #   tfd.MultivariateNormalDiag(
#      76   #       loc=tf.zeros(num_rade),
#      77   #       scale_diag=self._stddev_rade * tf.ones(num_rade)),
#      78   #   tfd.MultivariateNormalDiag(
#      79   #       loc=tf.zeros(num_vale),
#      80   #       scale_diag=self._stddev_vale * tf.ones(num_vale)),
#      81   #   tfd.MultivariateNormalDiag(
#      82   #       loc=tf.zeros(num_nhoh),
#      83   #       scale_diag=self._stddev_nhoh * tf.ones(num_nhoh)),
#      84   #   tfd.MultivariateNormalDiag(
#      85   #       loc=tf.zeros(num_h),
#      86   #       scale_diag=self._stddev_h * tf.ones(num_h)),
#      87   #   tfd.MultivariateNormalDiag(
#      88   #       loc=tf.zeros(num_no),
#      89   #       scale_diag=self._stddev_no * tf.ones(num_no)),
#      90   #   tfd.MultivariateNormalDiag(
#      91   #       loc=tf.zeros(num_hacc),
#      92   #       scale_diag=self._stddev_hacc * tf.ones(num_hacc)),
#      93   #   tfd.MultivariateNormalDiag(
#      94   #       loc=tf.zeros(num_hdon),
#      95   #       scale_diag=self._stddev_hdon * tf.ones(num_hdon)),
#      96   #   tfd.MultivariateNormalDiag(
#      97   #       loc=tf.zeros(num_rings),
#      98   #       scale_diag=self._stddev_rings * tf.ones(num_rings)),
#      99   #   tfd.MultivariateNormalDiag(
#     100   #       loc=tf.zeros(num_alring),
#     101   #       scale_diag=self._stddev_alring * tf.ones(num_alring)),
#     102   #   tfd.MultivariateNormalDiag(
#     103   #       loc=tf.zeros(num_aroring),
#     104   #       scale_diag=self._stddev_aroring * tf.ones(num_aroring)),
#     105   #   tfd.MultivariateNormalDiag(
#     106   #       loc=tf.zeros(num_satring),
#     107   #       scale_diag=self._stddev_satring * tf.ones(num_satring)),
#     108   #   tfd.MultivariateNormalDiag(
#     109   #       loc=tf.zeros(num_arocarb),
#     110   #       scale_diag=self._stddev_arocarb * tf.ones(num_arocarb)),
#     111   #   tfd.MultivariateNormalDiag(
#     112   #       loc=tf.zeros(num_arohet),
#     113   #       scale_diag=self._stddev_arohet * tf.ones(num_arohet)),
#     114   #   tfd.MultivariateNormalDiag(
#     115   #       loc=tf.zeros(num_het),
#     116   #       scale_diag=self._stddev_het * tf.ones(num_het)),
#     117   #   tfd.MultivariateNormalDiag(
#     118   #       loc=tf.zeros(num_rotbond),
#     119   #       scale_diag=self._stddev_rotbond * tf.ones(num_rotbond)),
#     120   #   tfd.MultivariateNormalDiag(
#     121   #       loc=tf.zeros(num_satcarb),
#     122   #       scale_diag=self._stddev_satcarb * tf.ones(num_satcarb)),
#     123   #   tfd.MultivariateNormalDiag(
#     124   #       loc=tf.zeros(num_sathet),
#     125   #       scale_diag=self._stddev_sathet * tf.ones(num_sathet)),
#     126   #   tfd.MultivariateNormalDiag(
#     127   #       loc=tf.zeros(num_c),
#     128   #       scale_diag=self._stddev_c * tf.ones(num_c)),
#     129   #   tfd.MultivariateNormalDiag(
#     130   #       loc=tf.zeros(num_n),
#     131   #       scale_diag=self._stddev_n * tf.ones(num_n)),
#     132   #   tfd.MultivariateNormalDiag(
#     133   #       loc=tf.zeros(num_f),
#     134   #       scale_diag=self._stddev_f * tf.ones(num_f)),
#     135   #   tfd.MultivariateNormalDiag(
#     136   #       loc=tf.zeros(num_hal),
#     137   #       scale_diag=self._stddev_hal * tf.ones(num_hal)),
#     138   #   tfd.MultivariateNormalDiag(
#     139   #       loc=tf.zeros(num_double),
#     140   #       scale_diag=self._stddev_double * tf.ones(num_double)),
#     141   #   tfd.MultivariateNormalDiag(
#     142   #       loc=tf.zeros(num_triple),
#     143   #       scale_diag=self._stddev_triple * tf.ones(num_triple)),
#     144   #   tfd.MultivariateNormalDiag(
#     145   #       loc=tf.zeros(num_maxabs),
#     146   #       scale_diag=self._stddev_maxabs * tf.ones(num_maxabs)),
#     147   #   tfd.MultivariateNormalDiag(
#     148   #       loc=tf.zeros(num_maxpart),
#     149   #       scale_diag=self._stddev_maxpart * tf.ones(num_maxpart)),
#     150   #   tfd.MultivariateNormalDiag(
#     151   #       loc=tf.zeros(num_minabs),
#     152   #       scale_diag=self._stddev_minabs * tf.ones(num_minabs)),
#     153   #   tfd.MultivariateNormalDiag(
#     154   #       loc=tf.zeros(num_minpart),
#     155   #       scale_diag=self._stddev_minpart * tf.ones(num_minpart)),
#     156     # This is the likelihood for the observed.
#     157     lambda effect_molwt, effect_hvatmolwt
#     158           #  effect_rade, effect_vale, effect_nhoh, effect_h, effect_no,
#     159           #  effect_hacc, effect_hdon, effect_rings, effect_alring, effect_aroring, effect_satring,
#     160           #  effect_arocarb, effect_arohet, effect_het, effect_rotbond, effect_satcarb, effect_sathet,
#     161           #  effect_c, effect_n, effect_f, effect_hal, effect_double, effect_triple, effect_maxabs,
#     162           #  effect_maxpart, effect_minpart, effect_minabs
#     163            : tfd.Independent(
#     164         tfd.Normal(
#     165             loc=(self._effect_service * X_train["Group"] +
# --> 166                 tf.gather(effect_molwt, X_train["MolWt"], axis=-1) +
#     167                 tf.gather(effect_hvatmolwt, X_train["HvAtMolWt"], axis=-1) +
#     168               #   tf.gather(effect_rade, X_train['RadE'], axis=-1) +
#     169               #   tf.gather(effect_vale, X_train['ValE'], axis=-1) +
#     170               #   tf.gather(effect_nhoh, X_train['NHOH'], axis=-1) +
#     171               #   tf.gather(effect_h, X_train['H'], axis=-1) +
#     172               #   tf.gather(effect_no, X_train['NO'], axis=-1) +
#     173               #   tf.gather(effect_hacc, X_train['HAcc'], axis=-1) +
#     174               #   tf.gather(effect_hdon, X_train['HDon'], axis=-1) +
#     175               #   tf.gather(effect_rings, X_train['Rings'], axis=-1) +
#     176               #   tf.gather(effect_alring, X_train['AlRing'], axis=-1) +
#     177               #   tf.gather(effect_aroring, X_train['AroRing'], axis=-1) +
#     178               #   tf.gather(effect_satring, X_train['SatRing'], axis=-1) +
#     179               #   tf.gather(effect_arocarb, X_train['AroCarb'], axis=-1) +
#     180               #   tf.gather(effect_arohet, X_train['AroHet'], axis=-1) +
#     181               #   tf.gather(effect_het, X_train['Heteroatoms'], axis=-1) +
#     182               #   tf.gather(effect_rotbond, X_train['RotBond'], axis=-1) +
#     183               #   tf.gather(effect_satcarb, X_train['SatCarb'], axis=-1) +
#     184               #   tf.gather(effect_sathet, X_train['SatHet'], axis=-1) +
#     185               #   tf.gather(effect_c, X_train['C'], axis=-1) +
#     186               #   tf.gather(effect_n, X_train['N'], axis=-1) +
#     187               #   tf.gather(effect_f, X_train['F'], axis=-1) +
#     188               #   tf.gather(effect_hal, X_train['Halogens'], axis=-1) +
#     189               #   tf.gather(effect_double, X_train['Double'], axis=-1) +
#     190               #   tf.gather(effect_triple, X_train['Triple'], axis=-1) +
#     191               #   tf.gather(effect_maxpart, X_train['MaxPartCh'], axis=-1) +
#     192               #   tf.gather(effect_maxabs, X_train['MaxAbsPartCh'], axis=-1) +
#     193               #   tf.gather(effect_minpart, X_train['MinPartCh'], axis=-1) +
#     194               #   tf.gather(effect_minabs, X_train['MinAbsPartCh'], axis=-1) +
#     195                 self._intercept),
#     196             scale=1.),
#     197             reinterpreted_batch_ndims=1)
#     198   ])
#     200   # To enable tracking of the trainable variables via the created distribution,
#     201   # we attach a reference to `self`. Since all TFP objects sub-class
#     202   # `tf.Module`, this means that the following is possible:
#     203   # LinearMixedEffectModel()(features_train).trainable_variables
#     204   # ==> tuple of all tf.Variables created by LinearMixedEffectModel.
#     205   model._to_track = self
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#     155   del filtered_tb
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# InvalidArgumentError: {{function_node __wrapped__GatherV2_device_/job:localhost/replica:0/task:0/device:CPU:0}} indices[14119] = 3147 is not in [0, 2875) [Op:GatherV2]

# %%
lmm_train.resolve_graph()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 lmm_train.resolve_graph()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/tensorflow_probability/python/distributions/joint_distribution_sequential.py:460, in _JointDistributionSequential.resolve_graph(self, distribution_names, leaf_name)
#     424 def resolve_graph(self, distribution_names=None, leaf_name='x'):
#     425   """Creates a `tuple` of `tuple`s of dependencies.
#     426
#     427   This function is **experimental**. That said, we encourage its use
#    (...)
#     458
#     459   """
# --> 460   distribution_names = self._flat_resolve_names(
#     461       distribution_names=distribution_names, leaf_name=leaf_name)
#     462   graph_parents = tuple(() if a is None else a for a in self._dist_fn_args)
#     463   return tuple(zip(distribution_names, graph_parents))
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/tensorflow_probability/python/distributions/joint_distribution_sequential.py:473, in _JointDistributionSequential._flat_resolve_names(self, distribution_names, leaf_name)
#     465 def _flat_resolve_names(self, distribution_names=None, leaf_name='x'):
#     466   # This function additionally depends on:
#     467   #   self._dist_fn_args
#     468   #   self._dist_fn_wrapped
#     469   if distribution_names is None or any(self._dist_fn_args):
#     470     # Extract user-passed `name` parameters from distribution instances.
#     471     instance_names = [
#     472         joint_distribution_lib.get_explicit_name_for_component(d)
# --> 473         for d in self._get_single_sample_distributions()]
#     474     distribution_names = _resolve_distribution_names(
#     475         self._dist_fn_args,
#     476         dist_names=distribution_names,
#     477         leaf_name=leaf_name,
#     478         instance_names=instance_names)
#     480   if len(set(distribution_names)) != len(distribution_names):
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/tensorflow_probability/python/distributions/joint_distribution.py:353, in JointDistribution._get_single_sample_distributions(self, candidate_dists)
#     351     ds = candidate_dists
#     352   else:
# --> 353     ds = self._execute_model(
#     354         seed=samplers.zeros_seed(),  # Constant seed for CSE.
#     355         sample_and_trace_fn=trace_distributions_only)
#     356   self._single_sample_distributions[graph_id] = ds
#     357 return ds
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/tensorflow_probability/python/distributions/joint_distribution.py:1047, in JointDistribution._execute_model(self, sample_shape, seed, value, stop_index, sample_and_trace_fn)
#    1045     if stop_index is not None and index == stop_index:
#    1046       break
# -> 1047     d = gen.send(next_value)
#    1048 except StopIteration:
#    1049   pass
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/tensorflow_probability/python/distributions/joint_distribution_sequential.py:399, in _JointDistributionSequential._model_coroutine(self)
#     397 xs = []
#     398 for dist_fn, args in zip(self._dist_fn_wrapped, self._dist_fn_args):
# --> 399   dist = dist_fn(*xs)
#     400   if not args:
#     401     dist = self.Root(dist)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/tensorflow_probability/python/distributions/joint_distribution_sequential.py:610, in _unify_call_signature.<locals>.dist_fn_wrapped(*xs)
#     605 if len(xs) < len(args):
#     606   raise ValueError(
#     607       'Internal Error: Too few inputs provided to {}-th distribution maker '
#     608       '(dist_fn: {}, expected: {}, saw: {}).'.format(
#     609           i, dist_fn, len(args), len(xs)))
# --> 610 return dist_fn(*reversed(xs[-len(args):]))
#
# Cell In[24], line 163, in LinearMixedEffectModel.__call__.<locals>.<lambda>(effect_molwt, effect_hvatmolwt, effect_rade, effect_vale, effect_nhoh, effect_h, effect_no, effect_hacc, effect_hdon, effect_rings, effect_alring, effect_aroring, effect_satring, effect_arocarb, effect_arohet, effect_het, effect_rotbond, effect_satcarb, effect_sathet, effect_c, effect_n, effect_f, effect_hal, effect_double, effect_triple, effect_maxabs, effect_maxpart, effect_minpart, effect_minabs)
#      66 def __call__(self, features):
#      67   model = tfd.JointDistributionSequential([
#      68     # Set up random effects.
#      69     tfd.MultivariateNormalDiag(
#      70         loc=tf.zeros(num_molwt, dtype=tf.dtypes.float32),
#      71         scale_diag=self._stddev_molwt * tf.ones(num_molwt)),
#      72     tfd.MultivariateNormalDiag(
#      73         loc=tf.zeros(num_hvmolwt),
#      74         scale_diag=self._stddev_hvmolwt * tf.ones(num_hvmolwt)),
#      75     tfd.MultivariateNormalDiag(
#      76         loc=tf.zeros(num_rade),
#      77         scale_diag=self._stddev_rade * tf.ones(num_rade)),
#      78     tfd.MultivariateNormalDiag(
#      79         loc=tf.zeros(num_vale),
#      80         scale_diag=self._stddev_vale * tf.ones(num_vale)),
#      81     tfd.MultivariateNormalDiag(
#      82         loc=tf.zeros(num_nhoh),
#      83         scale_diag=self._stddev_nhoh * tf.ones(num_nhoh)),
#      84     tfd.MultivariateNormalDiag(
#      85         loc=tf.zeros(num_h),
#      86         scale_diag=self._stddev_h * tf.ones(num_h)),
#      87     tfd.MultivariateNormalDiag(
#      88         loc=tf.zeros(num_no),
#      89         scale_diag=self._stddev_no * tf.ones(num_no)),
#      90     tfd.MultivariateNormalDiag(
#      91         loc=tf.zeros(num_hacc),
#      92         scale_diag=self._stddev_hacc * tf.ones(num_hacc)),
#      93     tfd.MultivariateNormalDiag(
#      94         loc=tf.zeros(num_hdon),
#      95         scale_diag=self._stddev_hdon * tf.ones(num_hdon)),
#      96     tfd.MultivariateNormalDiag(
#      97         loc=tf.zeros(num_rings),
#      98         scale_diag=self._stddev_rings * tf.ones(num_rings)),
#      99     tfd.MultivariateNormalDiag(
#     100         loc=tf.zeros(num_alring),
#     101         scale_diag=self._stddev_alring * tf.ones(num_alring)),
#     102     tfd.MultivariateNormalDiag(
#     103         loc=tf.zeros(num_aroring),
#     104         scale_diag=self._stddev_aroring * tf.ones(num_aroring)),
#     105     tfd.MultivariateNormalDiag(
#     106         loc=tf.zeros(num_satring),
#     107         scale_diag=self._stddev_satring * tf.ones(num_satring)),
#     108     tfd.MultivariateNormalDiag(
#     109         loc=tf.zeros(num_arocarb),
#     110         scale_diag=self._stddev_arocarb * tf.ones(num_arocarb)),
#     111     tfd.MultivariateNormalDiag(
#     112         loc=tf.zeros(num_arohet),
#     113         scale_diag=self._stddev_arohet * tf.ones(num_arohet)),
#     114     tfd.MultivariateNormalDiag(
#     115         loc=tf.zeros(num_het),
#     116         scale_diag=self._stddev_het * tf.ones(num_het)),
#     117     tfd.MultivariateNormalDiag(
#     118         loc=tf.zeros(num_rotbond),
#     119         scale_diag=self._stddev_rotbond * tf.ones(num_rotbond)),
#     120     tfd.MultivariateNormalDiag(
#     121         loc=tf.zeros(num_satcarb),
#     122         scale_diag=self._stddev_satcarb * tf.ones(num_satcarb)),
#     123     tfd.MultivariateNormalDiag(
#     124         loc=tf.zeros(num_sathet),
#     125         scale_diag=self._stddev_sathet * tf.ones(num_sathet)),
#     126     tfd.MultivariateNormalDiag(
#     127         loc=tf.zeros(num_c),
#     128         scale_diag=self._stddev_c * tf.ones(num_c)),
#     129     tfd.MultivariateNormalDiag(
#     130         loc=tf.zeros(num_n),
#     131         scale_diag=self._stddev_n * tf.ones(num_n)),
#     132     tfd.MultivariateNormalDiag(
#     133         loc=tf.zeros(num_f),
#     134         scale_diag=self._stddev_f * tf.ones(num_f)),
#     135     tfd.MultivariateNormalDiag(
#     136         loc=tf.zeros(num_hal),
#     137         scale_diag=self._stddev_hal * tf.ones(num_hal)),
#     138     tfd.MultivariateNormalDiag(
#     139         loc=tf.zeros(num_double),
#     140         scale_diag=self._stddev_double * tf.ones(num_double)),
#     141     tfd.MultivariateNormalDiag(
#     142         loc=tf.zeros(num_triple),
#     143         scale_diag=self._stddev_triple * tf.ones(num_triple)),
#     144     tfd.MultivariateNormalDiag(
#     145         loc=tf.zeros(num_maxabs),
#     146         scale_diag=self._stddev_maxabs * tf.ones(num_maxabs)),
#     147     tfd.MultivariateNormalDiag(
#     148         loc=tf.zeros(num_maxpart),
#     149         scale_diag=self._stddev_maxpart * tf.ones(num_maxpart)),
#     150     tfd.MultivariateNormalDiag(
#     151         loc=tf.zeros(num_minabs),
#     152         scale_diag=self._stddev_minabs * tf.ones(num_minabs)),
#     153     tfd.MultivariateNormalDiag(
#     154         loc=tf.zeros(num_minpart),
#     155         scale_diag=self._stddev_minpart * tf.ones(num_minpart)),
#     156     # This is the likelihood for the observed.
#     157     lambda effect_molwt, effect_hvatmolwt, effect_rade, effect_vale, effect_nhoh, effect_h, effect_no,
#     158            effect_hacc, effect_hdon, effect_rings, effect_alring, effect_aroring, effect_satring,
#     159            effect_arocarb, effect_arohet, effect_het, effect_rotbond, effect_satcarb, effect_sathet,
#     160            effect_c, effect_n, effect_f, effect_hal, effect_double, effect_triple, effect_maxabs,
#     161            effect_maxpart, effect_minpart, effect_minabs: tfd.Independent(
#     162         tfd.Normal(
# --> 163             loc=(self._effect_service * list_numerical["Group"] +
#     164                 tf.gather(effect_molwt, list_numerical["MolWt"], axis=-1) +
#     165                 tf.gather(effect_hvatmolwt, list_numerical["HvAtMolWt"], axis=-1) +
#     166                 tf.gather(effect_rade, list_numerical['RadE'], axis=-1) +
#     167                 tf.gather(effect_vale, list_numerical['ValE'], axis=-1) +
#     168                 tf.gather(effect_nhoh, list_numerical['NHOH'], axis=-1) +
#     169                 tf.gather(effect_h, list_numerical['H'], axis=-1) +
#     170                 tf.gather(effect_no, list_numerical['NO'], axis=-1) +
#     171                 tf.gather(effect_hacc, list_numerical['HAcc'], axis=-1) +
#     172                 tf.gather(effect_hdon, list_numerical['HDon'], axis=-1) +
#     173                 tf.gather(effect_rings, list_numerical['Rings'], axis=-1) +
#     174                 tf.gather(effect_alring, list_numerical['AlRing'], axis=-1) +
#     175                 tf.gather(effect_aroring, list_numerical['AroRing'], axis=-1) +
#     176                 tf.gather(effect_satring, list_numerical['SatRing'], axis=-1) +
#     177                 tf.gather(effect_arocarb, list_numerical['AroCarb'], axis=-1) +
#     178                 tf.gather(effect_arohet, list_numerical['AroHet'], axis=-1) +
#     179                 tf.gather(effect_het, list_numerical['Heteroatoms'], axis=-1) +
#     180                 tf.gather(effect_rotbond, list_numerical['RotBond'], axis=-1) +
#     181                 tf.gather(effect_satcarb, list_numerical['SatCarb'], axis=-1) +
#     182                 tf.gather(effect_sathet, list_numerical['SatHet'], axis=-1) +
#     183                 tf.gather(effect_c, list_numerical['C'], axis=-1) +
#     184                 tf.gather(effect_n, list_numerical['N'], axis=-1) +
#     185                 tf.gather(effect_f, list_numerical['F'], axis=-1) +
#     186                 tf.gather(effect_hal, list_numerical['Halogens'], axis=-1) +
#     187                 tf.gather(effect_double, list_numerical['Double'], axis=-1) +
#     188                 tf.gather(effect_triple, list_numerical['Triple'], axis=-1) +
#     189                 tf.gather(effect_maxpart, list_numerical['MaxPartCh'], axis=-1) +
#     190                 tf.gather(effect_maxabs, list_numerical['MaxAbsPartCh'], axis=-1) +
#     191                 tf.gather(effect_minpart, list_numerical['MinPartCh'], axis=-1) +
#     192                 tf.gather(effect_minabs, list_numerical['MinAbsPartCh'], axis=-1) +
#     193                 self._intercept),
#     194             scale=1.),
#     195             reinterpreted_batch_ndims=1)
#     196   ])
#     198   # To enable tracking of the trainable variables via the created distribution,
#     199   # we attach a reference to `self`. Since all TFP objects sub-class
#     200   # `tf.Module`, this means that the following is possible:
#     201   # LinearMixedEffectModel()(features_train).trainable_variables
#     202   # ==> tuple of all tf.Variables created by LinearMixedEffectModel.
#     203   model._to_track = self
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/indexes/base.py:5195, in Index.__getitem__(self, key)
#    5192     else:
#    5193         key = np.asarray(key, dtype=bool)
# -> 5195 result = getitem(key)
#    5196 # Because we ruled out integer above, we always get an arraylike here
#    5197 if result.ndim > 1:
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
