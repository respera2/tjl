# %%
import pandas as pd
import numpy as np
import pandas as pd
import os
from matplotlib import image
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
hv = pd.read_csv('/Users/reesaespera/Desktop/tjl/Havard Dataset/Full_Descriptors.csv')
nf = pd.read_csv('/Users/reesaespera/Desktop/tjl/Non-Fullerene Dataset/NF_Descriptors.csv')
cp = pd.read_csv('/Users/reesaespera/Desktop/tjl/Conjugated Polymers Dataset/CP_Data.csv')
dd = pd.read_csv('/Users/reesaespera/Desktop/tjl/Dopant Dataset/Dopant_Data.csv')

# %%
hv['Group'] = '1'
nf = nf.rename(columns={'smiles':'SMILES', 'HOMO_calc':'HOMO', 'LUMO_calc':'LUMO'})
nf['Group'] = '2'
cp = cp.rename(columns={'-HOMO(eV)':'HOMO','-LUMO(eV)':'LUMO', 'smiles':'SMILES'})
cp['Group'] = '3'
dd = dd.rename(columns={'smiles':'SMILES'}).drop(columns=['Unnamed: 0','HOMO - 1','LUMO + 1'])
dd['Group'] = '4'

# %%
dfs = [hv, nf, cp, dd]

result = pd.concat(dfs)

# %%
result
# Out:
#     Unnamed: 0                                             SMILES     HOMO  \
# 0          0.0  Cc1ccc(-c2c3cc(-c4ccc(-c5sc(-c6cccs6)c6cc(S(C)...  -0.1700
# 1          1.0  CN1c2ccccc2C(=C2c3ccc(-c4cccs4)cc3N(C)C2=O)C1=O\n  -0.1830
# 2          2.0  Cc1cc(-c2cc3c4nsnc4c(-c4cc(C)c(-c5cccs5)s4)cc3...  -0.1730
# 3          3.0  Cn1c2ccccc2c2ccc(-c3ccc(-c4ccc(C5=C(c6ccccc6)C...  -0.1580
# 4          4.0  Cc1cc(-c2c3cc(-c4cccs4)sc3c(-c3cc(C)c(C)s3)c3c...  -0.1700
# ..         ...                                                ...      ...
# 42         NaN                                        O=[W](=O)=O -11.4918
# 43         NaN           Cc1c(F)c(=C(C#N)C#N)c(F)c(F)c1=C(C#N)C#N  -9.1965
# 44         NaN       COC(=O)C(C#N)=c1c(F)c(F)c(=C(C#N)C#N)c(F)c1F  -9.2273
# 45         NaN  [C-]#[N+]C(C#N)=c1c(F)c(F)c(=C(C#N)C(=O)OCC(C)...  -9.0708
# 46         NaN  COc1ccc(N(c2ccc(OC)cc2)c2ccc(-c3ccc(N(c4ccc(OC...  -6.6339
#
#       LUMO  Molecular Weight  Heavy Atom Molecular Weight  \
# 0  -0.1180           763.162                      740.986
# 1  -0.1350           372.449                      356.321
# 2  -0.1330           600.866                      584.738
# 3  -0.1120           770.158                      734.878
# 4  -0.1370           899.194                      866.938
# ..     ...               ...                          ...
# 42 -3.5168           231.837                      231.837
# 43 -3.5970           272.189                      269.165
# 44 -3.6334           309.178                      306.154
# 45 -3.4558           407.367                      390.231
# 46  0.5733           608.738                      572.450
#
#     Max Absolute Partial Charge  Max Partial Charge  Min Abs Partial Charge  \
# 0                      0.223158            0.184422                0.184422
# 1                      0.310764            0.259055                0.259055
# 2                      0.172251            0.113593                0.113593
# 3                      0.343591            0.117083                0.117083
# 4                      0.308118            0.259140                0.259140
# ..                          ...                 ...                     ...
# 42                          NaN                 NaN                     NaN
# 43                     0.205833            0.171281                0.171281
# 44                     0.464876            0.348956                0.348956
# 45                     0.461271            0.349242                0.349242
# 46                     0.496766            0.118511                0.118511
#
#     Min Partial Charge  ...  H Count  C Count  N Count  F Count  \
# 0            -0.223158  ...       22       35        0        0
# 1            -0.310764  ...       16       22        2        0
# 2            -0.172251  ...       16       28        4        0
# 3            -0.343591  ...       35       47        1        0
# 4            -0.308118  ...       32       48        2        2
# ..                 ...  ...      ...      ...      ...      ...
# 42                 NaN  ...        0        0        0        0
# 43           -0.205833  ...        3       13        4        3
# 44           -0.464876  ...        3       13        3        4
# 45           -0.461271  ...       17       20        3        4
# 46           -0.496766  ...       36       40        2        0
#
#     Halogen Count  Double Bonds  Triple Bonds  Group  \
# 0               0             2             0      1
# 1               0             3             0      1
# 2               0             0             0      1
# 3               0             2             0      1
# 4               2             3             0      1
# ..            ...           ...           ...    ...
# 42              0             3             0      4
# 43              3             2             4      4
# 44              4             3             3      4
# 45              4             3             3      4
# 46              0             0             0      4
#
#                                               mol  Unnamed: 0.1
# 0                                             NaN           NaN
# 1                                             NaN           NaN
# 2                                             NaN           NaN
# 3                                             NaN           NaN
# 4                                             NaN           NaN
# ..                                            ...           ...
# 42  <rdkit.Chem.rdchem.Mol object at 0x2845fc120>          43.0
# 43  <rdkit.Chem.rdchem.Mol object at 0x2845fc190>          45.0
# 44  <rdkit.Chem.rdchem.Mol object at 0x2845fc200>          46.0
# 45  <rdkit.Chem.rdchem.Mol object at 0x2845fc270>          47.0
# 46  <rdkit.Chem.rdchem.Mol object at 0x2845fc2e0>          48.0
#
# [52683 rows x 36 columns]

# %%
dd
# Out:
#     Unnamed: 0.1     HOMO    LUMO  \
# 0              0  -9.0876  0.9016
# 1              1  -8.0247  2.5937
# 2              2  -9.5322  0.0302
# 3              3 -14.5217  1.6518
# 4              4  -7.0858 -0.3497
# 5              5  -7.8237  2.3482
# 6              6  -7.7932 -2.6762
# 7              7  -8.5182 -2.0641
# 8              8  -4.9377  1.0800
# 9              9  -4.9025  1.2849
# 10            10  -6.8527 -0.5898
# 11            11  -5.0177  0.2916
# 12            12  -6.4295  1.5528
# 13            13  -9.7439 -1.4984
# 14            14  -6.4538  1.4182
# 15            16  -5.5612  2.6916
# 16            17  -7.7107  3.0897
# 17            18  -8.0915  3.0476
# 18            19  -6.3701  1.6201
# 19            20  -8.6443 -4.3675
# 20            21  -9.6402 -4.1363
# 21            22  -7.2146  0.8870
# 22            23  -6.5441  1.4276
# 23            24  -7.9012  2.6480
# 24            25  -8.9712 -1.3795
# 25            26 -10.6251 -3.5029
# 26            27  -9.3695 -2.9151
# 27            28  -6.1264 -1.9020
# 28            29  -7.4812 -1.4253
# 29            30 -10.6168 -4.4549
# 30            31 -10.4262 -3.6495
# 31            32 -10.4344 -3.6327
# 32            33  -7.8268 -0.1421
# 33            34  -7.4619 -0.4813
# 34            35  -7.7797 -2.6526
# 35            36  -8.9901 -3.6600
# 36            37 -10.6541 -2.7308
# 37            38  -6.4550 -0.1434
# 38            39  -9.2600 -3.5787
# 39            40  -9.2525 -1.4956
# 40            41 -11.1031 -2.6228
# 41            42 -10.2725 -3.0066
# 42            43 -11.4918 -3.5168
# 43            45  -9.1965 -3.5970
# 44            46  -9.2273 -3.6334
# 45            47  -9.0708 -3.4558
# 46            48  -6.6339  0.5733
#
#                                               mol  \
# 0   <rdkit.Chem.rdchem.Mol object at 0x16c8d2dc0>
# 1   <rdkit.Chem.rdchem.Mol object at 0x16c8d2ea0>
# 2   <rdkit.Chem.rdchem.Mol object at 0x16c8d2e30>
# 3   <rdkit.Chem.rdchem.Mol object at 0x16c8d2f10>
# 4   <rdkit.Chem.rdchem.Mol object at 0x16c8d2ff0>
# 5   <rdkit.Chem.rdchem.Mol object at 0x16c8d3060>
# 6   <rdkit.Chem.rdchem.Mol object at 0x16c8d30d0>
# 7   <rdkit.Chem.rdchem.Mol object at 0x16c8d2f80>
# 8   <rdkit.Chem.rdchem.Mol object at 0x16c8d3140>
# 9   <rdkit.Chem.rdchem.Mol object at 0x16c8d31b0>
# 10  <rdkit.Chem.rdchem.Mol object at 0x16c8d3220>
# 11  <rdkit.Chem.rdchem.Mol object at 0x16c8d3290>
# 12  <rdkit.Chem.rdchem.Mol object at 0x16c8d3300>
# 13  <rdkit.Chem.rdchem.Mol object at 0x16c8d3370>
# 14  <rdkit.Chem.rdchem.Mol object at 0x16c8d33e0>
# 15  <rdkit.Chem.rdchem.Mol object at 0x16c8d34c0>
# 16  <rdkit.Chem.rdchem.Mol object at 0x16c8d3530>
# 17  <rdkit.Chem.rdchem.Mol object at 0x16c8d35a0>
# 18  <rdkit.Chem.rdchem.Mol object at 0x16c8d3610>
# 19  <rdkit.Chem.rdchem.Mol object at 0x16c8d3680>
# 20  <rdkit.Chem.rdchem.Mol object at 0x16c8d36f0>
# 21  <rdkit.Chem.rdchem.Mol object at 0x16c8d3760>
# 22  <rdkit.Chem.rdchem.Mol object at 0x16c8d37d0>
# 23  <rdkit.Chem.rdchem.Mol object at 0x16c8d3840>
# 24  <rdkit.Chem.rdchem.Mol object at 0x16c8d38b0>
# 25  <rdkit.Chem.rdchem.Mol object at 0x16c8d3920>
# 26  <rdkit.Chem.rdchem.Mol object at 0x16c8d3990>
# 27  <rdkit.Chem.rdchem.Mol object at 0x16c8d3a00>
# 28  <rdkit.Chem.rdchem.Mol object at 0x16c8d3a70>
# 29  <rdkit.Chem.rdchem.Mol object at 0x16c8d3ae0>
# 30  <rdkit.Chem.rdchem.Mol object at 0x16c8d3b50>
# 31  <rdkit.Chem.rdchem.Mol object at 0x16c8d3bc0>
# 32  <rdkit.Chem.rdchem.Mol object at 0x16c8d3c30>
# 33  <rdkit.Chem.rdchem.Mol object at 0x16c8d3ca0>
# 34  <rdkit.Chem.rdchem.Mol object at 0x16c8d3d10>
# 35  <rdkit.Chem.rdchem.Mol object at 0x16c8d3d80>
# 36  <rdkit.Chem.rdchem.Mol object at 0x16c8d3df0>
# 37  <rdkit.Chem.rdchem.Mol object at 0x16c8d3e60>
# 38  <rdkit.Chem.rdchem.Mol object at 0x16c8d3ed0>
# 39  <rdkit.Chem.rdchem.Mol object at 0x16c8d3f40>
# 40  <rdkit.Chem.rdchem.Mol object at 0x2845fc040>
# 41  <rdkit.Chem.rdchem.Mol object at 0x2845fc0b0>
# 42  <rdkit.Chem.rdchem.Mol object at 0x2845fc120>
# 43  <rdkit.Chem.rdchem.Mol object at 0x2845fc190>
# 44  <rdkit.Chem.rdchem.Mol object at 0x2845fc200>
# 45  <rdkit.Chem.rdchem.Mol object at 0x2845fc270>
# 46  <rdkit.Chem.rdchem.Mol object at 0x2845fc2e0>
#
#                                                SMILES  Molecular Weight  \
# 0                             O=C([O-])c1ccccc1.[Li+]           128.056
# 1                                      C1CN=C2CCCN2C1           124.187
# 2   Fc1[c-]c(F)c(F)c(F)c1F.Fc1[c-]c(F)c(F)c(F)c1F....           399.502
# 3                                              FB(F)F            67.806
# 4                    CN(C)c1ccc2cc3ccc(N(C)C)cc3nc2c1           265.360
# 5                     CCCC[N+](CCCC)(CCCC)CCCC.O.[F-]           279.484
# 6     CCN(CC)c1ccc2cc3ccc(=[N+](CC)CC)cc-3oc2c1.[Cl-]           358.913
# 7   CN(C)CCCN1C(=O)c2ccc3c4c(ccc(c24)C1=O)C(=O)N(C...           436.512
# 8                           C1=CC2=C3C=CC=CN3CCN2C=C1           184.242
# 9         C1=CN(Cc2ccccc2)C=CC1=C1C=CN(Cc2ccccc2)C=C1           338.454
# 10           C1=CSC(=c2c3nsnc3c(=C3SC=CS3)c3nsnc23)S1           396.594
# 11                         CNc1ccccc1N(C)Cc1ccc(C)cc1           240.350
# 12                 Cc1ccc(C2N(C)c3cc(C)c(C)cc3N2C)cc1           266.388
# 13  Fc1c(F)c(F)c(B(c2c(F)c(F)c(F)c(F)c2F)c2c(F)c(F...           511.980
# 14                        COc1ccccc1C1N(C)c2ccccc2N1C           254.333
# 15                         CN(C)C(C(N(C)C)N(C)C)N(C)C           202.346
# 16                                    C1CN=C2NCCCN2C1           139.202
# 17                              C1CN2CCCN3CCCN(C1)C23           181.283
# 18             Cc1cc2c(cc1C)N(C)C(c1ccc(N(C)C)cc1)N2C           295.430
# 19  N#CC(C#N)c1c(F)c(F)c2c(F)c(C(C#N)C#N)c(F)c(F)c...           364.208
# 20         N#Cc1c(F)c(C(C#N)C#N)c(C#N)c(F)c1C(C#N)C#N           292.208
# 21      COc1ccc(C2C=C(c3ccccc3)N(C)C(c3ccccc3)=C2)cc1           353.465
# 22                    Cc1cc2c(cc1C)N(C)C(c1ccccc1)N2C           252.361
# 23                                   C1CCC2=NCCCN2CC1           152.241
# 24    O=C1c2ccccc2C(=O)c2cc(S(=O)(=O)[O-])ccc21.[Na+]           310.262
# 25           N#CC(C#N)=c1c(F)c(F)c(=C(C#N)C#N)c(F)c1F           276.152
# 26                     N#CC(C#N)=c1ccc(=C(C#N)C#N)cc1           204.192
# 27              C1=CSC2=C(S1)SC(=C1SC3=C(SC=CS3)S1)S2           380.678
# 28  CN(C)c1ccc(C(=C2C=CC(=[N+](C)C)C=C2)c2ccc(N(C)...           407.989
# 29              N#CC(C#N)=C1C(=C(C#N)C#N)C1=C(C#N)C#N           228.174
# 30     CC(=O)C(C#N)=C1C(=C(C#N)C(C)=O)C1=C(C#N)C(C)=O           279.255
# 31                       [CH2-][n+]1ccn(C)c1C(=O)[O-]           139.134
# 32                     COc1ccccc1C1N(C)c2ccccc2N1C.Cl           290.794
# 33      CC1=CC(=C(C#N)C#N)C=C(/C=C/c2ccc(N(C)C)cc2)O1           303.365
# 34  CCN=c1ccc2c(-c3ccccc3C(=O)O)c3ccc(N(CC)CC)cc3o...           449.958
# 35   COC(=O)C(C#N)=c1c(F)c(F)c(=C(C#N)C(=O)OC)c(F)c1F           342.204
# 36  N#Cc1nc2c3nc(C#N)c(C#N)nc3c3nc(C#N)c(C#N)nc3c2...           384.282
# 37             Cn1c(-c2ccccc2O)[n+](C)c2ccccc21.[OH-]           256.305
# 38  [C-]#[N+]C(C#N)=c1c(F)c(F)c(=C(C#N)C(=O)OC)c(F...           309.178
# 39                                                 II           253.808
# 40                                       O=[Mo](=O)=O           143.937
# 41                                                O=O            31.998
# 42                                        O=[W](=O)=O           231.837
# 43           Cc1c(F)c(=C(C#N)C#N)c(F)c(F)c1=C(C#N)C#N           272.189
# 44       COC(=O)C(C#N)=c1c(F)c(F)c(=C(C#N)C#N)c(F)c1F           309.178
# 45  [C-]#[N+]C(C#N)=c1c(F)c(F)c(=C(C#N)C(=O)OCC(C)...           407.367
# 46  COc1ccc(N(c2ccc(OC)cc2)c2ccc(-c3ccc(N(c4ccc(OC...           608.738
#
#     Heavy Atom Molecular Weight  Max Absolute Partial Charge  \
# 0                       123.016                     1.000000
# 1                       112.091                     0.360293
# 2                       399.502                     2.000000
# 3                        67.806                     0.762028
# 4                       246.208                     0.377598
# 5                       241.180                     1.000000
# 6                       331.697                     1.000000
# 7                       408.288                     0.309332
# 8                       172.146                     0.344507
# 9                       316.278                     0.349866
# 10                      392.562                     0.172125
# 11                      220.190                     0.386447
# 12                      244.212                     0.348797
# 13                      511.980                     0.264566
# 14                      236.189                     0.496320
# 15                      176.138                     0.291624
# 16                      126.098                     0.356169
# 17                      162.131                     0.275369
# 18                      270.230                     0.377661
# 19                      362.192                     0.205690
# 20                      290.192                     0.205084
# 21                      330.281                     0.496768
# 22                      232.201                     0.348797
# 23                      136.113                     0.360308
# 24                      303.206                     1.000000
# 25                      276.152                     0.202876
# 26                      200.160                     0.191621
# 27                      376.646                     0.088397
# 28                      377.749                     1.000000
# 29                      228.174                     0.191620
# 30                      270.183                     0.293683
# 31                      132.078                     0.551252
# 32                      271.642                     0.496320
# 33                      286.229                     0.461992
# 34                      423.750                     1.000000
# 35                      336.156                     0.464876
# 36                      384.282                     0.229962
# 37                      240.177                     0.869681
# 38                      306.154                     0.464876
# 39                      253.808                     0.000000
# 40                      143.937                          NaN
# 41                       31.998                     0.000000
# 42                      231.837                          NaN
# 43                      269.165                     0.205833
# 44                      306.154                     0.464876
# 45                      390.231                     0.461271
# 46                      572.450                     0.496766
#
#     Max Partial Charge  Min Abs Partial Charge  ...  Saturated Carbocycles  \
# 0             1.000000                0.544815  ...                      0
# 1             0.098910                0.098910  ...                      0
# 2             2.000000                0.278185  ...                      0
# 3             0.762028                0.254009  ...                      0
# 4             0.072987                0.072987  ...                      0
# 5             0.078603                0.078603  ...                      0
# 6             0.203163                0.203163  ...                      0
# 7             0.260887                0.260887  ...                      0
# 8             0.064746                0.064746  ...                      0
# 9             0.046969                0.046969  ...                      0
# 10            0.116255                0.116255  ...                      0
# 11            0.060183                0.060183  ...                      0
# 12            0.127577                0.127577  ...                      0
# 13            0.264566                0.204099  ...                      0
# 14            0.131208                0.131208  ...                      0
# 15            0.091058                0.091058  ...                      0
# 16            0.193425                0.193425  ...                      0
# 17            0.119134                0.119134  ...                      0
# 18            0.127579                0.127579  ...                      0
# 19            0.169796                0.169796  ...                      0
# 20            0.162015                0.162015  ...                      0
# 21            0.118379                0.118379  ...                      0
# 22            0.127576                0.127576  ...                      0
# 23            0.098842                0.098842  ...                      0
# 24            1.000000                0.744035  ...                      0
# 25            0.171486                0.171486  ...                      0
# 26            0.136378                0.136378  ...                      0
# 27            0.071761                0.071761  ...                      0
# 28            0.198959                0.198959  ...                      0
# 29            0.137771                0.137771  ...                      1
# 30            0.170460                0.170460  ...                      1
# 31            0.200131                0.200131  ...                      0
# 32            0.131208                0.131208  ...                      0
# 33            0.136639                0.136639  ...                      0
# 34            0.335817                0.335817  ...                      0
# 35            0.348956                0.348956  ...                      0
# 36            0.177295                0.177295  ...                      0
# 37            0.292697                0.292697  ...                      0
# 38            0.348956                0.348956  ...                      0
# 39            0.000000                0.000000  ...                      0
# 40                 NaN                     NaN  ...                      0
# 41            0.000000                0.000000  ...                      0
# 42                 NaN                     NaN  ...                      0
# 43            0.171281                0.171281  ...                      0
# 44            0.348956                0.348956  ...                      0
# 45            0.349242                0.349242  ...                      0
# 46            0.118511                0.118511  ...                      0
#
#     Saturated Heterocycles  H Count  C Count  N Count  F Count  Halogen Count  \
# 0                        0        5        7        0        0              0
# 1                        1       12        7        2        0              0
# 2                        0        0       12        0       10             10
# 3                        0        0        0        0        3              3
# 4                        0       19       17        3        0              0
# 5                        0       38       16        1        1              1
# 6                        0       27       21        2        0              1
# 7                        0       28       24        4        0              0
# 8                        0       12       12        2        0              0
# 9                        0       22       24        2        0              0
# 10                       0        4       12        4        0              0
# 11                       0       20       16        2        0              0
# 12                       0       22       18        2        0              0
# 13                       0        0       18        0       15             15
# 14                       0       18       16        2        0              0
# 15                       0       26       10        4        0              0
# 16                       1       13        7        3        0              0
# 17                       3       19       10        3        0              0
# 18                       0       25       19        3        0              0
# 19                       0        2       16        4        6              6
# 20                       0        2       14        6        2              2
# 21                       0       23       25        1        0              0
# 22                       0       20       17        2        0              0
# 23                       1       16        9        2        0              0
# 24                       0        7       14        0        0              0
# 25                       0        0       12        4        4              4
# 26                       0        4       12        4        0              0
# 27                       0        4       10        0        0              0
# 28                       0       30       25        3        0              1
# 29                       0        0       12        6        0              0
# 30                       0        9       15        3        0              0
# 31                       0        7        6        2        0              0
# 32                       0       19       16        2        0              1
# 33                       0       17       19        3        0              0
# 34                       0       26       26        2        0              1
# 35                       0        6       14        2        4              4
# 36                       0        0       18       12        0              0
# 37                       0       16       15        2        0              0
# 38                       0        3       13        3        4              4
# 39                       0        0        0        0        0              2
# 40                       0        0        0        0        0              0
# 41                       0        0        0        0        0              0
# 42                       0        0        0        0        0              0
# 43                       0        3       13        4        3              3
# 44                       0        3       13        3        4              4
# 45                       0       17       20        3        4              4
# 46                       0       36       40        2        0              0
#
#     Double Bonds  Triple Bonds  Group
# 0              1             0      4
# 1              1             0      4
# 2              0             0      4
# 3              0             0      4
# 4              0             0      4
# 5              0             0      4
# 6              1             0      4
# 7              4             0      4
# 8              5             0      4
# 9              5             0      4
# 10             4             0      4
# 11             0             0      4
# 12             0             0      4
# 13             0             0      4
# 14             0             0      4
# 15             0             0      4
# 16             1             0      4
# 17             0             0      4
# 18             0             0      4
# 19             0             4      4
# 20             0             6      4
# 21             2             0      4
# 22             0             0      4
# 23             1             0      4
# 24             4             0      4
# 25             2             4      4
# 26             2             4      4
# 27             5             0      4
# 28             4             0      4
# 29             3             6      4
# 30             6             3      4
# 31             1             0      4
# 32             0             0      4
# 33             4             2      4
# 34             2             0      4
# 35             4             2      4
# 36             0             6      4
# 37             0             0      4
# 38             3             3      4
# 39             0             0      4
# 40             3             0      4
# 41             1             0      4
# 42             3             0      4
# 43             2             4      4
# 44             3             3      4
# 45             3             3      4
# 46             0             0      4
#
# [47 rows x 35 columns]

# %%
combo = pd.concat([hv, dd, cp, nf], ignore_index=True)
# columns = ['HOMO', 'LUMO', 'SMILES', 'Molecular Weight', 'Heavy Atom Molecular Weight', 'Max Absolute Partial Charge', 'Max Partial Charge', 
#          'Min Abs Partial Charge', 'Min Partial Charge', 'Radical Electrons', 'Valence Electrons', 'NHOH Count', 'NO Count',
#          'H Acceptors', 'H Donors', 'Ring Count', 'Aliphatic Rings', 'Aromatic Rings', 'Saturated Rings', 'Aromatic Carbocycles',
#          'Aromatic Heterocycles', 'Heteroatoms', 'Rotatable Bonds', 'Saturated Carbocycles', 'Saturated Heterocycles', 'H Count',
#          'C Count', 'N Count', 'F Count', 'Halogen Count', 'Double Bonds', 'Triple Bonds']

# combo = combo.rename(columns={'Molecular Weight':'MolWt', 'Heavy Atom Molecular Weight':'HvAtMolWt', 
#                             'Max Absolute Partial Charge':'MaxAbsPartCh', 'Max Partial Charge':'MaxPartCh',
#                             'Min Abs Partial Charge':'MinAbsPartCh', 'Radical Electrons':'RadE', 'Valence Electrons':'ValE',
#                             'NHOH Count':'NHOH', 'NO Count':'NO', 'H Acceptors':'HAcc', 'H Donors':'HDon', 'Ring Count':'Rings',
#                             'Aliphatic Rings':'AlRing', 'Aromatic Rings':'AroRing', 'Saturated Rings':'SatRing',
#                             'Aromatic Carbocycles':'AroCarb', 'Aromatic Heterocycles':'AroHet', 'Rotatable Bonds':'RotBond',
#                             'Saturated Carbocycles':'SatCarb', 'Saturated Heterocycles':'SatHet', 'H Count':'H', 'C Count':'C',
#                             'N Count':'N', 'F Count':'F', 'Halogen Count':'Halogens', 'Double Bonds':'Double', 'Triple Bonds':'Triple',
#                             'Min Partial Charge':'MinPartCh'})
# combo = combo.dropna(axis=1)

# combo = combo.drop(columns=['Unnamed: 0', 'Unnamed: 0.1', 'mol'])

# %%
combo
# Out:
#        Unnamed: 0                                             SMILES  \
# 0             0.0  Cc1ccc(-c2c3cc(-c4ccc(-c5sc(-c6cccs6)c6cc(S(C)...
# 1             1.0  CN1c2ccccc2C(=C2c3ccc(-c4cccs4)cc3N(C)C2=O)C1=O\n
# 2             2.0  Cc1cc(-c2cc3c4nsnc4c(-c4cc(C)c(-c5cccs5)s4)cc3...
# 3             3.0  Cn1c2ccccc2c2ccc(-c3ccc(-c4ccc(C5=C(c6ccccc6)C...
# 4             4.0  Cc1cc(-c2c3cc(-c4cccs4)sc3c(-c3cc(C)c(C)s3)c3c...
# ...           ...                                                ...
# 52678     51251.0  CN1C(=O)C(=Cc2ccsc2C(=O)c2cocc2-c2ccnc(-c3scc4...
# 52679     51252.0  CN1C(=O)C(=Cc2c(F)cc(-c3c(-c4ccncn4)sc4ccc(C#N...
# 52680     51253.0  CN1C(=O)C(=Cc2nccc(-c3sc4ccc(C#N)cc4c3-c3cc(F)...
# 52681     51254.0  CN1C(=O)C(=Cc2ccc3nc(-c4sc5ccc(C#N)cc5c4-c4ccc...
# 52682     51255.0  CN1C(=O)C(=Cc2nc3ccc(-c4c(-c5nc6ccccc6o5)sc5cc...
#
#            HOMO      LUMO  Molecular Weight  Heavy Atom Molecular Weight  \
# 0     -0.170000 -0.118000           763.162                      740.986
# 1     -0.183000 -0.135000           372.449                      356.321
# 2     -0.173000 -0.133000           600.866                      584.738
# 3     -0.158000 -0.112000           770.158                      734.878
# 4     -0.170000 -0.137000           899.194                      866.938
# ...         ...       ...               ...                          ...
# 52678 -5.658348 -3.153557           594.721                      576.577
# 52679 -6.630212 -3.389053           555.576                      541.464
# 52680 -6.634797 -2.933484           555.576                      541.464
# 52681 -6.471826 -3.272118           559.563                      542.427
# 52682 -6.400935 -3.489946           559.563                      542.427
#
#        Max Absolute Partial Charge  Max Partial Charge  \
# 0                         0.223158            0.184422
# 1                         0.310764            0.259055
# 2                         0.172251            0.113593
# 3                         0.343591            0.117083
# 4                         0.308118            0.259140
# ...                            ...                 ...
# 52678                     0.471102            0.332907
# 52679                     0.332907            0.332907
# 52680                     0.332907            0.332907
# 52681                     0.443458            0.332907
# 52682                     0.436696            0.332907
#
#        Min Abs Partial Charge  Min Partial Charge  ...   Jsc_calc  FF_calc  \
# 0                    0.184422           -0.223158  ...        NaN      NaN
# 1                    0.259055           -0.310764  ...        NaN      NaN
# 2                    0.113593           -0.172251  ...        NaN      NaN
# 3                    0.117083           -0.343591  ...        NaN      NaN
# 4                    0.259140           -0.308118  ...        NaN      NaN
# ...                       ...                 ...  ...        ...      ...
# 52678                0.332907           -0.471102  ...  39.914101     0.65
# 52679                0.268330           -0.268330  ...   6.346322     0.65
# 52680                0.268328           -0.268328  ...   1.164496     0.65
# 52681                0.332907           -0.443458  ...   6.886551     0.65
# 52682                0.332907           -0.436696  ...  15.495977     0.65
#
#        EQE_calc  PCE_calib  Voc_calib  Jsc_calib  FF_calib  EQE_calib  \
# 0           NaN        NaN        NaN        NaN       NaN        NaN
# 1           NaN        NaN        NaN        NaN       NaN        NaN
# 2           NaN        NaN        NaN        NaN       NaN        NaN
# 3           NaN        NaN        NaN        NaN       NaN        NaN
# 4           NaN        NaN        NaN        NaN       NaN        NaN
# ...         ...        ...        ...        ...       ...        ...
# 52678      0.65   5.998603   0.988194  93.423325      0.65       0.65
# 52679      0.65   0.828925   0.903275  14.123518      0.65       0.65
# 52680      0.65   0.266871   1.404496   2.924341      0.65       0.65
# 52681      0.65   1.140859   0.988578  17.761047      0.65       0.65
# 52682      0.65   1.675230   0.815527  31.614295      0.65       0.65
#
#        PCE_cdiff  PCE_calib_plus
# 0            NaN             NaN
# 1            NaN             NaN
# 2            NaN             NaN
# 3            NaN             NaN
# 4            NaN             NaN
# ...          ...             ...
# 52678   1.987973        1.758867
# 52679   0.288346        0.000000
# 52680   0.133209        0.000000
# 52681   0.501939        0.000000
# 52682   0.456868        0.479331
#
# [52683 rows x 51 columns]

# %%
result.to_csv('All.csv')
